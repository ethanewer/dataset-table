# %%
import pandas as pd

df = pd.read_csv("datasets.csv")

# %%
df[df["is_code_swe_terminal"] & df["is_agent_sft"]][
    [k for k in df.keys() if k not in ["is_code_swe_terminal", "is_agent_sft", "dataset_url", "is_agent_rl", "aux_models"]]
]
# Out:
#                             dataset_name  \
# 5        nvidia/Nemotron-SFT-OpenCode-v1
# 7        nvidia/Nemotron-Terminal-Corpus
# 10            nvidia/Nemotron-SFT-SWE-v2
# 13   Sellopale/OpenThoughts-Agent-v1-SFT
# 14  lambda/hermes-agent-reasoning-traces
# 15         TeichAI/DeepSeek-v4-Pro-Agent
# 16              open-thoughts/AgentTrove
# 17         nebius/SWE-agent-trajectories
# 18  AlienKevin/SWE-ZERO-12M-trajectories
#
#                                             reasoning  \
# 5                                               false
# 7                                                true
# 10                                      [false, true]
# 13                                               true
# 14                                       [true, true]
# 15                                               true
# 16  [true, true, true, true, true, true, true, tru...
# 17                                 [true, true, true]
# 18                                               true
#
# ...
